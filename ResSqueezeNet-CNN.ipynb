# %%
from __future__ import print_function, division
import numpy as np
from glob import glob
import pandas as pd
import os
from tqdm import tqdm
output_path = os.path.join('..','input')
import matplotlib.pyplot as plt
from skimage.util._montage import montage
from skimage.color import label2rgb
# %matplotlib inline

# %%
import h5py
with h5py.File('all_patches.hdf5') as luna_h5:
    all_slices = luna_h5['ct_slices'].value
    all_classes = luna_h5['slice_class'].value
    print('data', all_slices.shape, 'classes', all_classes.shape)
# Out:
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\ipykernel\__main__.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   from ipykernel import kernelapp as app
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\ipykernel\__main__.py:3: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   app.launch_new_instance()
# data (6691, 64, 64) classes (6691, 1)
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\ipykernel\__main__.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (12, 6))
plt_args = dict(cmap = 'bone', vmin = -600, vmax = 300)
ax1.imshow(montage(all_slices[np.random.choice(np.where(all_classes>0.5)[0],size = 64)]), **plt_args)
ax1.set_title('Malignant Tiles')
ax2.imshow(montage(all_slices[np.random.choice(np.where(all_classes<0.5)[0],size = 64)]), **plt_args)
ax2.set_title('Benign Tiles')
# Out:
# Text(0.5, 1.0, 'Benign Tiles')

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
from keras.engine.topology import get_source_inputs
from keras.utils import get_file
from keras.utils import layer_utils
from keras.layers.merge import add

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3
    
    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    x = BatchNormalization()(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    x = BatchNormalization()(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


def _shortcut(x, residual):
    x_shape = K.int_shape(x)
    residual_shape = K.int_shape(residual)
    if K.image_data_format() == 'channels_last':
        ROW_AXIS = 1
        COL_AXIS = 2
        CHANNEL_AXIS = 3
    else:
        CHANNEL_AXIS = 1
        ROW_AXIS = 2
        COL_AXIS = 3    
    stride_width = int(round(x_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(x_shape[COL_AXIS] / residual_shape[COL_AXIS]))
    equal_channels = x_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]
    
    shortcut = x
    # 如果通道数 维度不同 用1x1 conv 调节
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Convolution2D(filters=residual_shape[CHANNEL_AXIS],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal")(x)

    return add([shortcut, residual])

def res_squeeze_block(res_squeeze_id,num_squeeze,num_expand):
    def f(x):
        residual = fire_module(x, fire_id=res_squeeze_id, squeeze=num_squeeze, expand=num_expand)
        return _shortcut(x, residual)

    return f

def ResSqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)
    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = res_squeeze_block(res_squeeze_id=3, num_squeeze=16, num_expand=64)(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = res_squeeze_block(res_squeeze_id=5, num_squeeze=32, num_expand=128)(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = res_squeeze_block(res_squeeze_id=7, num_squeeze=48, num_expand=192)(x)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = res_squeeze_block(res_squeeze_id=9, num_squeeze=64, num_expand=256)(x)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='ResSqueezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model
# Out:
# Using TensorFlow backend.

# %%
import keras
lung_node_cnn = ResSqueezeNet(input_shape = (64, 64, 1), 
                           weights = None, classes = 2,
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = keras.optimizers.Adam(lr=0.001, decay=1e-5)

# Let's train the model using RMSprop
lung_node_cnn.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
lung_node_cnn.summary()
# Out:
# Model: "ResSqueezenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 1)    4           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 31, 31, 64)   640         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 31, 31, 64)   0           conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 15, 15, 64)   0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 15, 15, 16)   1040        pool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 15, 15, 16)   64          fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 15, 15, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 15, 16)   64          fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 15, 15, 64)   1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 15, 15, 64)   9280        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 15, 15, 64)   0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 15, 15, 64)   0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 15, 15, 128)  0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 15, 15, 16)   2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15, 15, 16)   64          fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 15, 15, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 15, 15, 16)   64          fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 15, 15, 64)   1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 15, 15, 64)   9280        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 15, 15, 64)   0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 15, 15, 64)   0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 15, 15, 128)  0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 15, 15, 128)  0           fire2/concat[0][0]
#                                                                  fire3/concat[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 7, 7, 128)    0           add_1[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 7, 7, 32)     4128        pool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 32)     128         fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 7, 7, 32)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 32)     128         fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 7, 7, 128)    4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 7, 7, 128)    36992       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 7, 7, 128)    0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 7, 7, 128)    0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 7, 7, 256)    0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 7, 7, 32)     8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 32)     128         fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 7, 7, 32)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 32)     128         fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 7, 7, 128)    4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 7, 7, 128)    36992       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 7, 7, 128)    0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 7, 7, 128)    0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 7, 7, 256)    0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 7, 7, 256)    0           fire4/concat[0][0]
#                                                                  fire5/concat[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 3, 3, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1 (Conv2D)       (None, 3, 3, 48)     12336       pool5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 3, 3, 48)     192         fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1 (Activati (None, 3, 3, 48)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 3, 3, 48)     192         fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1 (Conv2D)        (None, 3, 3, 192)    9408        fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3 (Conv2D)        (None, 3, 3, 192)    83136       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1 (Activatio (None, 3, 3, 192)    0           fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3 (Activatio (None, 3, 3, 192)    0           fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire6/concat (Concatenate)      (None, 3, 3, 384)    0           fire6/relu_expand1x1[0][0]
#                                                                  fire6/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1 (Conv2D)       (None, 3, 3, 48)     18480       fire6/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 3, 3, 48)     192         fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1 (Activati (None, 3, 3, 48)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 3, 3, 48)     192         fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1 (Conv2D)        (None, 3, 3, 192)    9408        fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3 (Conv2D)        (None, 3, 3, 192)    83136       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1 (Activatio (None, 3, 3, 192)    0           fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3 (Activatio (None, 3, 3, 192)    0           fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/concat (Concatenate)      (None, 3, 3, 384)    0           fire7/relu_expand1x1[0][0]
#                                                                  fire7/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 3, 3, 384)    0           fire6/concat[0][0]
#                                                                  fire7/concat[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1 (Conv2D)       (None, 3, 3, 64)     24640       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 3, 3, 64)     256         fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1 (Activati (None, 3, 3, 64)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 3, 3, 64)     256         fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1 (Conv2D)        (None, 3, 3, 256)    16640       fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3 (Conv2D)        (None, 3, 3, 256)    147712      batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1 (Activatio (None, 3, 3, 256)    0           fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3 (Activatio (None, 3, 3, 256)    0           fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/concat (Concatenate)      (None, 3, 3, 512)    0           fire8/relu_expand1x1[0][0]
#                                                                  fire8/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1 (Conv2D)       (None, 3, 3, 64)     32832       fire8/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 3, 3, 64)     256         fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1 (Activati (None, 3, 3, 64)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 3, 3, 64)     256         fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1 (Conv2D)        (None, 3, 3, 256)    16640       fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3 (Conv2D)        (None, 3, 3, 256)    147712      batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1 (Activatio (None, 3, 3, 256)    0           fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3 (Activatio (None, 3, 3, 256)    0           fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/concat (Concatenate)      (None, 3, 3, 512)    0           fire9/relu_expand1x1[0][0]
#                                                                  fire9/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 3, 3, 512)    0           fire8/concat[0][0]
#                                                                  fire9/concat[0][0]
# __________________________________________________________________________________________________
# drop9 (Dropout)                 (None, 3, 3, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv10 (Conv2D)                 (None, 3, 3, 2)      1026        drop9[0][0]
# __________________________________________________________________________________________________
# relu_conv10 (Activation)        (None, 3, 3, 2)      0           conv10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2)            0           relu_conv10[0][0]
# __________________________________________________________________________________________________
# loss (Activation)               (None, 2)            0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 724,934
# Trainable params: 723,652
# Non-trainable params: 1,282
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
X_vec = (np.expand_dims(all_slices,-1) - np.mean(all_slices))/np.std(all_slices)

y_vec = to_categorical(all_classes)
X_train, X_test, y_train, y_test = train_test_split(X_vec, y_vec, 
                                                   train_size = 0.75,
                                                   random_state = 1, 
                                                   stratify = all_classes)

# %%
from sklearn.metrics import classification_report
y_pred_proba = lung_node_cnn.predict(X_test)
y_pred = np.argmax(y_pred_proba,1)
print('')
print(classification_report(np.argmax(y_test,1),
                      y_pred))
lung_node_cnn.save('ResSQNet-10.h5')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77      1041
#            1       0.00      0.00      0.00       632
#
#     accuracy                           0.62      1673
#    macro avg       0.31      0.50      0.38      1673
# weighted avg       0.39      0.62      0.48      1673
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
for i in range(100):
    loss_history += [lung_node_cnn.fit(X_train, y_train, 
              validation_data=(X_test, y_test),
                               shuffle = True,
                               batch_size = 32,
                               epochs = 1)]
# Out:
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.2141 - val_accuracy: 0.9534
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.2473 - val_accuracy: 0.9540
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.2409 - val_accuracy: 0.9426
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1881 - val_accuracy: 0.9552
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1600 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 8.0840e-04 - accuracy: 0.9996 - val_loss: 0.1638 - val_accuracy: 0.9623
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1886 - val_accuracy: 0.9594
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1684 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1741 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.1729 - val_accuracy: 0.9582
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.1481 - val_accuracy: 0.9564
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.1930 - val_accuracy: 0.9611
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1795 - val_accuracy: 0.9594
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.2113 - val_accuracy: 0.9594
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.2205 - val_accuracy: 0.9588
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0060 - accuracy: 0.9968 - val_loss: 0.3046 - val_accuracy: 0.9444
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.1594 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1644 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 9.1659e-04 - accuracy: 0.9998 - val_loss: 0.1772 - val_accuracy: 0.9623
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.1659 - val_accuracy: 0.9665
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0101 - accuracy: 0.9976 - val_loss: 0.2208 - val_accuracy: 0.9546
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.1744 - val_accuracy: 0.9582
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1810 - val_accuracy: 0.9617
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 19s 4ms/step - loss: 4.6898e-04 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9617

# %%
from sklearn.metrics import classification_report
y_pred_proba = lung_node_cnn.predict(X_test)
y_pred = np.argmax(y_pred_proba,1)
print('')
print(classification_report(np.argmax(y_test,1),
                      y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      1041
#            1       0.96      0.94      0.95       632
#
#     accuracy                           0.96      1673
#    macro avg       0.96      0.96      0.96      1673
# weighted avg       0.96      0.96      0.96      1673

# %%
from IPython import display
def use_svg_display():
    # 用矢量图显示
    display.set_matplotlib_formats('svg')

def get_labels(labels):
    text_labels = ['Benign', 'Malignant']
    return [text_labels[int(i)] for i in labels]

def show_fashion_mnist(images, labels):
    use_svg_display()
    # 这里的_表示我们忽略（不使用）的变量
    _, figs = plt.subplots(1, len(images), figsize=(12, 12))
    for f, img, lbl in zip(figs, images, labels):
        f.imshow(img.reshape(64,64))
        f.set_title(lbl)
        f.axes.get_xaxis().set_visible(False)
        f.axes.get_yaxis().set_visible(False)
    plt.show()

true_labels = get_labels(np.argmax(y_test,1))
pred_labels = get_labels(y_pred)
titles = [true + '\n' + pred for true, pred in zip(true_labels, pred_labels)]

for i in range(0,40,10):
    show_fashion_mnist(X_test[i:i+10], titles[i:i+10])

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(np.argmax(y_test, 1), y_pred_proba[:,1])
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'CNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend()

# %%
epich = np.cumsum(np.concatenate(
    [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
_ = ax1.plot(epich,
             np.concatenate([mh.history['loss'] for mh in loss_history]),
             'b-',
             epich, np.concatenate(
        [mh.history['val_loss'] for mh in loss_history]), 'r-')
ax1.legend(['Training', 'Validation'])
ax1.set_title('Loss')

_ = ax2.plot(epich, np.concatenate(
    [mh.history['accuracy'] for mh in loss_history]), 'b-',
                 epich, np.concatenate(
        [mh.history['val_accuracy'] for mh in loss_history]),
                 'r-')
ax2.legend(['Training', 'Validation'])
ax2.set_title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')
