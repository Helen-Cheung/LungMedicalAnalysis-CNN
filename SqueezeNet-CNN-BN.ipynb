# %%
from __future__ import print_function, division
import numpy as np
from glob import glob
import pandas as pd
import os
from tqdm import tqdm
output_path = os.path.join('..','input')
import matplotlib.pyplot as plt
from skimage.util._montage import montage
from skimage.color import label2rgb
# %matplotlib inline

# %%
import h5py
with h5py.File('all_patches.hdf5') as luna_h5:
    all_slices = luna_h5['ct_slices'].value
    all_classes = luna_h5['slice_class'].value
    print('data', all_slices.shape, 'classes', all_classes.shape)
# Out:
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\ipykernel\__main__.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   from ipykernel import kernelapp as app
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\ipykernel\__main__.py:3: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   app.launch_new_instance()
# data (6691, 64, 64) classes (6691, 1)
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\ipykernel\__main__.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (12, 6))
plt_args = dict(cmap = 'bone', vmin = -600, vmax = 300)
ax1.imshow(montage(all_slices[np.random.choice(np.where(all_classes>0.5)[0],size = 64)]), **plt_args)
ax1.set_title('Malignant Tiles')
ax2.imshow(montage(all_slices[np.random.choice(np.where(all_classes<0.5)[0],size = 64)]), **plt_args)
ax2.set_title('Benign Tiles')
# Out:
# Text(0.5, 1.0, 'Benign Tiles')

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
from keras.engine.topology import get_source_inputs
from keras.utils import get_file
from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3
    
    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    x = BatchNormalization()(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    x = BatchNormalization()(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
import keras
lung_node_cnn = SqueezeNet(input_shape = (64, 64, 1), 
                           weights = None, classes = 2,
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = keras.optimizers.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
lung_node_cnn.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
lung_node_cnn.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 1)    4           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 31, 31, 64)   640         batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 31, 31, 64)   0           conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 15, 15, 64)   0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 15, 15, 16)   1040        pool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 15, 15, 16)   64          fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 15, 15, 16)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 15, 15, 16)   64          fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 15, 15, 64)   1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 15, 15, 64)   9280        batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 15, 15, 64)   0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 15, 15, 64)   0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 15, 15, 128)  0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 15, 15, 16)   2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 15, 15, 16)   64          fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 15, 15, 16)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 15, 15, 16)   64          fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 15, 15, 64)   1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 15, 15, 64)   9280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 15, 15, 64)   0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 15, 15, 64)   0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 15, 15, 128)  0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 7, 7, 128)    0           fire3/concat[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 7, 7, 32)     4128        pool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 7, 7, 32)     128         fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 7, 7, 32)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 7, 7, 32)     128         fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 7, 7, 128)    4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 7, 7, 128)    36992       batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 7, 7, 128)    0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 7, 7, 128)    0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 7, 7, 256)    0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 7, 7, 32)     8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 7, 7, 32)     128         fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 7, 7, 32)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 7, 7, 32)     128         fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 7, 7, 128)    4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 7, 7, 128)    36992       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 7, 7, 128)    0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 7, 7, 128)    0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 7, 7, 256)    0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 3, 3, 256)    0           fire5/concat[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1 (Conv2D)       (None, 3, 3, 48)     12336       pool5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 3, 3, 48)     192         fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1 (Activati (None, 3, 3, 48)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 3, 3, 48)     192         fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1 (Conv2D)        (None, 3, 3, 192)    9408        fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3 (Conv2D)        (None, 3, 3, 192)    83136       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1 (Activatio (None, 3, 3, 192)    0           fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3 (Activatio (None, 3, 3, 192)    0           fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire6/concat (Concatenate)      (None, 3, 3, 384)    0           fire6/relu_expand1x1[0][0]
#                                                                  fire6/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1 (Conv2D)       (None, 3, 3, 48)     18480       fire6/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 3, 3, 48)     192         fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1 (Activati (None, 3, 3, 48)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 3, 3, 48)     192         fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1 (Conv2D)        (None, 3, 3, 192)    9408        fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3 (Conv2D)        (None, 3, 3, 192)    83136       batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1 (Activatio (None, 3, 3, 192)    0           fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3 (Activatio (None, 3, 3, 192)    0           fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/concat (Concatenate)      (None, 3, 3, 384)    0           fire7/relu_expand1x1[0][0]
#                                                                  fire7/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1 (Conv2D)       (None, 3, 3, 64)     24640       fire7/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 3, 3, 64)     256         fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1 (Activati (None, 3, 3, 64)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 3, 3, 64)     256         fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1 (Conv2D)        (None, 3, 3, 256)    16640       fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3 (Conv2D)        (None, 3, 3, 256)    147712      batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1 (Activatio (None, 3, 3, 256)    0           fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3 (Activatio (None, 3, 3, 256)    0           fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/concat (Concatenate)      (None, 3, 3, 512)    0           fire8/relu_expand1x1[0][0]
#                                                                  fire8/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1 (Conv2D)       (None, 3, 3, 64)     32832       fire8/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 3, 3, 64)     256         fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1 (Activati (None, 3, 3, 64)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 3, 3, 64)     256         fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1 (Conv2D)        (None, 3, 3, 256)    16640       fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3 (Conv2D)        (None, 3, 3, 256)    147712      batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1 (Activatio (None, 3, 3, 256)    0           fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3 (Activatio (None, 3, 3, 256)    0           fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/concat (Concatenate)      (None, 3, 3, 512)    0           fire9/relu_expand1x1[0][0]
#                                                                  fire9/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# drop9 (Dropout)                 (None, 3, 3, 512)    0           fire9/concat[0][0]
# __________________________________________________________________________________________________
# conv10 (Conv2D)                 (None, 3, 3, 2)      1026        drop9[0][0]
# __________________________________________________________________________________________________
# relu_conv10 (Activation)        (None, 3, 3, 2)      0           conv10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2)            0           relu_conv10[0][0]
# __________________________________________________________________________________________________
# loss (Activation)               (None, 2)            0           global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 724,934
# Trainable params: 723,652
# Non-trainable params: 1,282
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
X_vec = (np.expand_dims(all_slices,-1) - np.mean(all_slices))/np.std(all_slices)

y_vec = to_categorical(all_classes)
X_train, X_test, y_train, y_test = train_test_split(X_vec, y_vec, 
                                                   train_size = 0.75,
                                                   random_state = 1, 
                                                   stratify = all_classes)

# %%
from sklearn.metrics import classification_report
y_pred_proba = lung_node_cnn.predict(X_test)
y_pred = np.argmax(y_pred_proba,1)
print('')
print(classification_report(np.argmax(y_test,1),
                      y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1041
#            1       0.38      1.00      0.55       632
#
#     accuracy                           0.38      1673
#    macro avg       0.19      0.50      0.27      1673
# weighted avg       0.14      0.38      0.21      1673
# D:\Users\asus\anaconda3\envs\keras\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
for i in range(500):
    loss_history += [lung_node_cnn.fit(X_train, y_train, 
              validation_data=(X_test, y_test),
                               shuffle = True,
                               batch_size = 32,
                               epochs = 1)]
# Out:
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 25s 5ms/step - loss: 0.6419 - accuracy: 0.6331 - val_loss: 0.6656 - val_accuracy: 0.6222
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.5826 - accuracy: 0.6941 - val_loss: 0.7385 - val_accuracy: 0.6252
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.4953 - accuracy: 0.7682 - val_loss: 0.6730 - val_accuracy: 0.6707
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.4090 - accuracy: 0.8117 - val_loss: 0.4248 - val_accuracy: 0.8093
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.3208 - accuracy: 0.8659 - val_loss: 0.4211 - val_accuracy: 0.8045
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.2613 - accuracy: 0.8930 - val_loss: 0.3488 - val_accuracy: 0.8583
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 3.4086e-04 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9683
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 2.0446e-04 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 2.8593e-04 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 1.0336e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 7.1001e-05 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.0581e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9677
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.2340 - val_accuracy: 0.9576
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 9.0554e-04 - accuracy: 0.9998 - val_loss: 0.2061 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.2522 - val_accuracy: 0.9570
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.2267 - val_accuracy: 0.9617
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.2068 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.1996 - val_accuracy: 0.9623
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 5.6374e-04 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.6227e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 9.1048e-05 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 1.6364e-04 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9659
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 5.3463e-04 - accuracy: 0.9998 - val_loss: 0.2048 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 1.6682e-04 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.0464e-04 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9659
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 2.4161e-04 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 3.8533e-05 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 8.7108e-05 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9677
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 8.5223e-05 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9665
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3003 - val_accuracy: 0.9486
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.2002 - val_accuracy: 0.9576
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.1558 - val_accuracy: 0.9594
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1537 - val_accuracy: 0.9623
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 4.7227e-04 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 3.4834e-04 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.3728e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 9.0199e-05 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9671
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 8.6068e-05 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9665
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.4423e-04 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.6519e-04 - accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 1.0963e-04 - accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 6.4244e-04 - accuracy: 0.9998 - val_loss: 0.2015 - val_accuracy: 0.9617
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 4.2501e-04 - accuracy: 0.9998 - val_loss: 0.1819 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 6.0508e-05 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9629
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 1.4262e-04 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.1162e-04 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 6.5511e-04 - accuracy: 0.9998 - val_loss: 0.1980 - val_accuracy: 0.9617
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.2187 - val_accuracy: 0.9576
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.2652 - val_accuracy: 0.9582
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.2219 - val_accuracy: 0.9594
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0039 - accuracy: 0.9982 - val_loss: 0.2017 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.1702 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 7.8876e-04 - accuracy: 0.9996 - val_loss: 0.1726 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 3.1028e-04 - accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 3.9597e-04 - accuracy: 0.9998 - val_loss: 0.1753 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.2146 - val_accuracy: 0.9576
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1859 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 1.0325e-04 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9665
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.2396e-04 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9629
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 4.3598e-04 - accuracy: 0.9998 - val_loss: 0.2150 - val_accuracy: 0.9600
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.2441 - val_accuracy: 0.9570
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 23s 5ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.2442 - val_accuracy: 0.9528
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.1866 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.2081 - val_accuracy: 0.9605
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1966 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 3.7199e-04 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0093 - accuracy: 0.9986 - val_loss: 0.2098 - val_accuracy: 0.9540
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.1833 - val_accuracy: 0.9605
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 6.3260e-04 - accuracy: 0.9998 - val_loss: 0.1612 - val_accuracy: 0.9665
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 2.4004e-04 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.2590e-04 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9629
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 1.2446e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9647
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 6.6028e-05 - accuracy: 1.0000 - val_loss: 0.1719 - val_accuracy: 0.9641
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 7.7656e-05 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9611
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 6.9404e-05 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.9653
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 5.3232e-05 - accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 0.9635
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 6.8649e-04 - accuracy: 0.9998 - val_loss: 0.2304 - val_accuracy: 0.9594
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 2.4655e-04 - accuracy: 1.0000 - val_loss: 0.1922 - val_accuracy: 0.9629
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 21s 4ms/step - loss: 3.1594e-04 - accuracy: 0.9998 - val_loss: 0.2045 - val_accuracy: 0.9629
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 4.1667e-04 - accuracy: 0.9998 - val_loss: 0.2140 - val_accuracy: 0.9611
# Train on 5018 samples, validate on 1673 samples
# Epoch 1/1
# 5018/5018 [==============================] - 20s 4ms/step - loss: 5.0953e-04 - accuracy: 0.9998 - val_loss: 0.2102 - val_accuracy: 0.9635

# %%
epich = np.cumsum(np.concatenate(
    [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
_ = ax1.plot(epich,
             np.concatenate([mh.history['loss'] for mh in loss_history]),
             'b-',
             epich, np.concatenate(
        [mh.history['val_loss'] for mh in loss_history]), 'r-')
ax1.legend(['Training', 'Validation'])
ax1.set_title('Loss')

_ = ax2.plot(epich, np.concatenate(
    [mh.history['accuracy'] for mh in loss_history]), 'b-',
                 epich, np.concatenate(
        [mh.history['val_accuracy'] for mh in loss_history]),
                 'r-')
ax2.legend(['Training', 'Validation'])
ax2.set_title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
from sklearn.metrics import classification_report
y_pred_proba = lung_node_cnn.predict(X_test)
y_pred = np.argmax(y_pred_proba,1)
print('')
print(classification_report(np.argmax(y_test,1),
                      y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1041
#            1       0.96      0.94      0.95       632
#
#     accuracy                           0.96      1673
#    macro avg       0.96      0.96      0.96      1673
# weighted avg       0.96      0.96      0.96      1673

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(np.argmax(y_test, 1), y_pred_proba[:,1])
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'CNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend()
